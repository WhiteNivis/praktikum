# %% [markdown]
# # Исследование объявлений о продаже квартир

# %% [markdown]
# Как формируется рыночная стоимость недвижимости? Какие параметры и как влияют на формирование цены? Исследование объявлений о продаже квартир позволит построить автоматизированную систему, позволяющую отвечать на эти вопросы и выявлять аномалии и мошенническую деятельность.
#
# <font color='green'>Цель</font>
#
# Цель исследования состоит в том, чтобы научиться определять рыночную стоимость объектов недвижимости.
#
# <font color='green'>Задачи</font>
#
# В ходе исследования мы должны определить параметры, влияющие на формирование рыночной стоимости недвижимости.
#
# <font color='green'>Файлы</font>
#
# - `real_estate_data.csv` - файл с данными для исследования.
#
# <font color='green'>Столбцы</font>
#
# * `airports_nearest` — расстояние до ближайшего аэропорта в метрах (м)
# * `balcony` — число балконов
# * `ceiling_height` — высота потолков (м)
# * `cityCenters_nearest` — расстояние до центра города (м)
# * `days_exposition` — сколько дней было размещено объявление (от публикации до снятия)
# * `first_day_exposition` — дата публикации
# * `floors_total` — всего этажей в доме
# * `is_apartment` — апартаменты (булев тип)
# * `kitchen_area` — площадь кухни в квадратных метрах (м²)
# * `last_price` — цена на момент снятия с публикации
# * `living_area` — жилая площадь в квадратных метрах(м²)
# * `locality_name` — название населённого пункта
# * `open_plan` — свободная планировка (булев тип)
# * `parks_around3000` — число парков в радиусе 3 км
# * `parks_nearest` — расстояние до ближайшего парка (м)
# * `ponds_around3000` — число водоёмов в радиусе 3 км
# * `ponds_nearest` — расстояние до ближайшего водоёма (м)
# * `rooms` — число комнат
# * `studio` — квартира-студия (булев тип)
# * `total_area` — площадь квартиры в квадратных метрах (м²)
# * `total_images` — число фотографий квартиры в объявлении

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Стиль-заголовков" data-toc-modified-id="Стиль-заголовков-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Стиль заголовков</a></span></li><li><span><a href="#Обработка-пропусков" data-toc-modified-id="Обработка-пропусков-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Обработка пропусков</a></span></li><li><span><a href="#Замена-типа-данных" data-toc-modified-id="Замена-типа-данных-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Замена типа данных</a></span></li><li><span><a href="#Обработка-дубликатов" data-toc-modified-id="Обработка-дубликатов-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Обработка дубликатов</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучаем-параметры:-площадь,-цена,-число-комнат,-высота-потолков." data-toc-modified-id="Изучаем-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучаем параметры: площадь, цена, число комнат, высота потолков.</a></span></li><li><span><a href="#Изучаем-время-продажи-квартиры" data-toc-modified-id="Изучаем-время-продажи-квартиры-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изучаем время продажи квартиры</a></span></li><li><span><a href="#Изучаем-факторы-больше-всего-влияющие-на-стоимость-квартиры" data-toc-modified-id="Изучаем-факторы-больше-всего-влияющие-на-стоимость-квартиры-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Изучаем факторы больше всего влияющие на стоимость квартиры</a></span><ul class="toc-item"><li><span><a href="#Зависимость-цены-квартиры-от-площади" data-toc-modified-id="Зависимость-цены-квартиры-от-площади-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Зависимость цены квартиры от площади</a></span></li><li><span><a href="#Зависимость-цены-квартиры-от-числа-комнат" data-toc-modified-id="Зависимость-цены-квартиры-от-числа-комнат-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Зависимость цены квартиры от числа комнат</a></span></li><li><span><a href="#Зависимость-цены-квартиры-от-удаленности-от-центра" data-toc-modified-id="Зависимость-цены-квартиры-от-удаленности-от-центра-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Зависимость цены квартиры от удаленности от центра</a></span></li><li><span><a href="#Зависимость-цены-квартиры-от-этажа" data-toc-modified-id="Зависимость-цены-квартиры-от-этажа-4.3.4"><span class="toc-item-num">4.3.4&nbsp;&nbsp;</span>Зависимость цены квартиры от этажа</a></span></li><li><span><a href="#Зависимость-цены-квартиры-от-даты-размещения" data-toc-modified-id="Зависимость-цены-квартиры-от-даты-размещения-4.3.5"><span class="toc-item-num">4.3.5&nbsp;&nbsp;</span>Зависимость цены квартиры от даты размещения</a></span></li><li><span><a href="#Топ-10-населённых-пунктов-с-наибольшим-числом-объявлений" data-toc-modified-id="Топ-10-населённых-пунктов-с-наибольшим-числом-объявлений-4.3.6"><span class="toc-item-num">4.3.6&nbsp;&nbsp;</span>Топ-10 населённых пунктов с наибольшим числом объявлений</a></span></li><li><span><a href="#Определение-границ-центра-Санкт-Петербурга" data-toc-modified-id="Определение-границ-центра-Санкт-Петербурга-4.3.7"><span class="toc-item-num">4.3.7&nbsp;&nbsp;</span>Определение границ центра Санкт-Петербурга</a></span></li><li><span><a href="#Анализ-сегмента-квартир-в-центре-Санкт-Петербурга" data-toc-modified-id="Анализ-сегмента-квартир-в-центре-Санкт-Петербурга-4.3.8"><span class="toc-item-num">4.3.8&nbsp;&nbsp;</span>Анализ сегмента квартир в центре Санкт-Петербурга</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# ## Изучение данных из файла

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('/ML/datasets/real_estate_data.csv', sep = '\t')

# %%
data.sample(n=5, random_state=1).T
# Out:
#                                         17338                13876  \
# total_images                                5                   12
# last_price                          3300000.0            2290000.0
# total_area                               47.0                 40.0
# first_day_exposition      2018-03-30T00:00:00  2016-01-17T00:00:00
# rooms                                       1                    2
# ceiling_height                            3.0                  3.0
# floors_total                             10.0                  3.0
# living_area                               NaN                 27.0
# floor                                       4                    2
# is_apartment                              NaN                False
# studio                                  False                False
# open_plan                               False                False
# kitchen_area                              NaN                  7.4
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# В названиях столбцов видны нарушения стиля:
#
#     Строчные буквы сочетаются с прописными.
#     Не используется "змеиный_регистр".
#
# Количество значений в столбцах различается. Визуально присутствует много значений 'NaN'.

# %%
data.describe().T
# Out:
#                        count          mean           std      min         25%  \
# total_images         23699.0  9.858475e+00  5.682529e+00      0.0        6.00
# last_price           23699.0  6.541549e+06  1.088701e+07  12190.0  3400000.00
# total_area           23699.0  6.034865e+01  3.565408e+01     12.0       40.00
# rooms                23699.0  2.070636e+00  1.078405e+00      0.0        1.00
# ceiling_height       14504.0  2.771499e+00  1.261056e+00      1.0        2.52
# floors_total         23613.0  1.067382e+01  6.597173e+00      1.0        5.00
# living_area          21796.0  3.445785e+01  2.203045e+01      2.0       18.60
# floor                23699.0  5.892358e+00  4.885249e+00      1.0        2.00
# kitchen_area         21421.0  1.056981e+01  5.905438e+00      1.3        7.00
# balcony              12180.0  1.150082e+00  1.071300e+00      0.0        0.00
# airports_nearest     18157.0  2.879367e+04  1.263088e+04      0.0    18585.00
# ...

# %% [markdown]
# Есть рад значений, которые вызывают сомнения.
# Например:
# - rooms = 0
# - ceiling_height = 1, 100
# - living_area = 2
# - airports_nearest = 0
# - days_exposition = 1580.0

# %% [markdown]
# **Вывод**

# %% [markdown]
# В таблице представлены данные о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет.
# Предварительно можно говорить о достаточности данных для исследования, но стоит отметить значительное кол-во пропусков. Значения некоторых параметров вызывают сомнения и требуют дополнительной обработки.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Стиль заголовков

# %%
print(data.columns)
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'cityCenters_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# Переименуем столбцы:
# * `'cityCenters_nearest'` → `'city_сenters_nearest'`;
# * `'parks_around3000'` → `'parks_around_3000'`;
# * `'ponds_around3000'` → `'ponds_around_3000'`;

# %%
data = data.rename(columns={'cityCenters_nearest':'city_сenters_nearest', 'parks_around3000':'parks_around_3000',
                            'ponds_around3000':'ponds_around_3000' })

# %% [markdown]
# Проверим результат.

# %%
print(data.columns)
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_сenters_nearest',
#        'parks_around_3000', 'parks_nearest', 'ponds_around_3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# **Вывод**

# %% [markdown]
# Откорректированы названия столбцов.
#
#  - Из названий убраны прописные буквы.
#  - Применен "змеиный регистр".

# %% [markdown]
# ### Обработка пропусков

# %% [markdown]
# Создадим функцию для подсчета пропусков в данных.

# %%
def percent_nan(df):
    percent_nan = pd.DataFrame(data.isnull().sum()/len(data)*100).round(2) 
    sum_nan = pd.DataFrame(data.isnull().sum())
    df = sum_nan.merge(percent_nan, on=percent_nan.index, how='left')
    df.columns = ['column', 'count_NaN', 'percent_NaN'] 
    return df

# %% [markdown]
# Проверим ее работу.

# %%
percent_nan(data)
# Out:
#                   column  count_NaN  percent_NaN
# 0           total_images          0         0.00
# 1             last_price          0         0.00
# 2             total_area          0         0.00
# 3   first_day_exposition          0         0.00
# 4                  rooms          0         0.00
# 5         ceiling_height       9195        38.80
# 6           floors_total         86         0.36
# 7            living_area       1903         8.03
# 8                  floor          0         0.00
# 9           is_apartment      20924        88.29
# 10                studio          0         0.00
# 11             open_plan          0         0.00
# 12          kitchen_area       2278         9.61
# 13               balcony      11519        48.61
# 14         locality_name         49         0.21
# 15      airports_nearest       5542        23.38
# 16  city_сenters_nearest       5519        23.29
# 17     parks_around_3000       5518        23.28
# ...

# %% [markdown]
# Стоит отметить, что в таблице представлены 2 типа данных: первые вписаны пользователем, вторые — получены автоматически на основе картографических данных.

# %% [markdown]
# `ceiling_height`

# %%
data['ceiling_height'].isna().sum()
# Out:
# 9195

# %% [markdown]
# Доля пропусков по столбцу `'ceiling_height'` составляет 38,8%, что составляет значительную часть выборки. Вероятно, что пропущенные данные  не были вписаны пользователями в объявление.

# %% [markdown]
# Рассмотрим статистичексие данные по столбцу `'ceiling_height'`.

# %%
data['ceiling_height'].describe()
# Out:
# count    14504.000000
# mean         2.771499
# std          1.261056
# min          1.000000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Попробуем посмотреть, есть ли связь между высотой потолков и с расстоянием до центра. Для этого построим диаграмму рассеивания.

# %%
data.plot(x='city_сenters_nearest', y='ceiling_height', kind='scatter', figsize=(16, 6), grid=True) 
plt.xticks([1000, 8000, 18000, 25000, 35000, 45000, 55000])
plt.xlabel('Расстояние до центра')
plt.ylabel('Высота потолков (м)')
plt.ylim(2.3, 5) 
plt.xlim(0, 55000)
# Out:
# (0.0, 55000.0)

# %% [markdown]
# На графике видно, что определенная зависимость имеется. Объединим данные в зависимости от удаленности от центра в следующие группы:
#
# - (0-1000]
# - (1000-8000]
# - (8000-18000]
# - (> 18000)
#
# Для этого создадим функцию.

# %%
def city_сenters_nearest_categoty(value):
    
    if value <= 1000:
        return '(0-1000]'
    if value <= 6000:
        return '(1000-8000]'
    if value <= 18000:
        return '(8000-18000]'
    return '(> 18000)'

# %% [markdown]
# Созданим новый столбец с данными и присвоим категории с помощью функции.

# %%
data['city_сenters_nearest_cut'] = data['city_сenters_nearest'].apply(city_сenters_nearest_categoty)
data.head(5).T
# Out:
#                                             0                    1  \
# total_images                               20                    7
# last_price                         13000000.0            3350000.0
# total_area                              108.0                 40.4
# first_day_exposition      2019-03-07T00:00:00  2018-12-04T00:00:00
# rooms                                       3                    1
# ceiling_height                            2.7                  NaN
# floors_total                             16.0                 11.0
# living_area                              51.0                 18.6
# floor                                       8                    1
# is_apartment                              NaN                  NaN
# studio                                  False                False
# open_plan                               False                False
# kitchen_area                             25.0                 11.0
# ...

# %% [markdown]
# Найдем значения медианы для данных столбца `'ceiling_height'` в каждой группе.

# %%
data.pivot_table(index=['city_сenters_nearest_cut'],values='ceiling_height', aggfunc='median')
# Out:
#                           ceiling_height
# city_сenters_nearest_cut
# (0-1000]                           3.200
# (1000-8000]                        3.075
# (8000-18000]                       2.640
# (> 18000)                          2.600

# %% [markdown]
# Используем эти значения для замены пропусков в столбце `'ceiling_height'`.

# %%
data.loc[(data['city_сenters_nearest_cut'] == '(0-1000]') & (data['ceiling_height'].isnull()), 'ceiling_height'] = 3.2
data.loc[(data['city_сenters_nearest_cut'] == '(1000-8000]') & (data['ceiling_height'].isnull()), 'ceiling_height'] = 3.075 
data.loc[(data['city_сenters_nearest_cut'] == '(8000-18000]') & (data['ceiling_height'].isnull()), 'ceiling_height'] = 2.64
data.loc[(data['city_сenters_nearest_cut'] == '(> 18000)') & (data['ceiling_height'].isnull()), 'ceiling_height'] = 2.6

# %% [markdown]
# Посчитаем количество пропусков.

# %%
data['ceiling_height'].isna().sum()
# Out:
# 0

# %% [markdown]
# `floors_total`

# %%
data['floors_total'].isna().sum()
# Out:
# 86

# %% [markdown]
# Доля пропусков по столбцу `'floors_total'` составляет 0,36%, что составляет незначительную часть выборки. Вероятно, что пропущенные данные не были указаны в объявлении и не подтянулись автоматически при формировании объявления.
#
# Учитывая, что информация о том находится ли квартира на первом/последнем этаже важна при продаже, оставим пропущенные значения без изменения.

# %% [markdown]
# `living_area`

# %%
data['living_area'].isna().sum()
# Out:
# 1903

# %% [markdown]
# Доля пропусков по столбцу `'living_area'` составляет 8,03%. Вероятно, что пропущенные данные не были указаны в объявлении.
#
# Найдем коэффициент корреляции Пирсона для общей и жилой площади квартиры.

# %%
data['total_area'].corr(data['living_area'])
# Out:
# 0.9395373338721495

# %% [markdown]
# Корреляция сильная.

# %% [markdown]
# Проверим все ли данные удовлетворяют условию `(living_area + kitchen_area) <= total_area`

# %%
data['check'] = data['total_area'] < (data['living_area'] + data['kitchen_area'])
data['check'].sum()
# Out:
# 64

# %%
data.query('check == True').head(3)
# Out:
#      total_images  last_price  total_area first_day_exposition  rooms  \
# 184             7   2600000.0       30.20  2018-02-14T00:00:00      1
# 545             9   4700000.0       23.80  2018-12-28T00:00:00      1
# 551             8   3100000.0       31.59  2018-03-08T00:00:00      1
#
#      ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 184            2.65           9.0        26.10      5          NaN  ...
# 545            2.64          18.0        20.00      9          NaN  ...
# 551            2.70          19.0        30.55      2          NaN  ...
#
#        locality_name  airports_nearest  city_сenters_nearest  \
# 184  Санкт-Петербург           13952.0               15031.0
# 545  Санкт-Петербург            9731.0               11849.0
# 551   посёлок Мурино               NaN                   NaN
#
#      parks_around_3000 parks_nearest  ponds_around_3000  ponds_nearest  \
# 184                0.0           NaN                1.0          824.0
# ...

# %% [markdown]
# Нашлось 64 объявления, в которых данные по площадям некорректные. Для этих объявлений откорректируем значения `'living_area'`.

# %%
data.loc[data['check'] == True, 'living_area'] = (data['total_area'] -  data['kitchen_area']).round(2)
data['check'] = data['total_area'] < (data['living_area'] + data['kitchen_area'])
data['check'].sum()
# Out:
# 0

# %% [markdown]
# Теперь все данные удовлетворяют заданному условию.

# %% [markdown]
# Посчитаем коэффициент отношения жилой площади к общей.

# %%
(data['living_area'] / data['total_area']).mean()
# Out:
# 0.5643381179441167

# %% [markdown]
# Заменим пропущенные значения, применив полученный коэффициент к общей площади.

# %%
data.loc[data['living_area'].isnull(), 'living_area'] = data['total_area'] * 0.5628303495971638

# %% [markdown]
# Проверим, что все данные по прежнему удовлетворяют условию `(living_area + kitchen_area) <= total_area`.

# %%
data['check'].sum()
# Out:
# 0

# %% [markdown]
# Посчитаем кол-во пропущенных значений.

# %%
data['living_area'].isna().sum()
# Out:
# 0

# %%
data.drop(['check'], axis = 1).head(3)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1            2.60          11.0         18.6      1          NaN  ...
# 2            2.64           5.0         34.3      4          NaN  ...
#
#    balcony    locality_name  airports_nearest  city_сenters_nearest  \
# 0      NaN  Санкт-Петербург           18863.0               16028.0
# 1      2.0   посёлок Шушары           12817.0               18603.0
# 2      0.0  Санкт-Петербург           21741.0               13933.0
#
#   parks_around_3000  parks_nearest  ponds_around_3000  ponds_nearest  \
# ...

# %% [markdown]
# `is_apartment`

# %%
data['is_apartment'].isna().sum()
# Out:
# 20924

# %% [markdown]
# Доля пропусков по столбцу `'is_apartment'` составляет 88,29%. Вероятно, что пропущенные данные не были указаны в объявлении. Оценим итоговую долю апартаментов, если все пропущенные значения мы заменим на False. Сравним ее с текущими данными Яндекс Недвижимости по Санкт-Петербургу и ЛО.

# %%
data['is_apartment'].value_counts()
# Out:
# False    2725
# True       50
# Name: is_apartment, dtype: int64

# %% [markdown]
# - 0.2% доля апартаментов при замене пропусков на False
# - 1.65% текущая доля апартаментов по Санкт-Петербургу и ЛО в Яндекс Недвижимости.
#
# Доли значительно отличаются, оставим пропуски по столбцу `'is_apartment'` без изменений.

# %% [markdown]
# `kitchen_area`

# %%
data['kitchen_area'].isna().sum()
# Out:
# 2278

# %% [markdown]
# Доля пропусков по столбцу `'kitchen_area'` составляет 9,61%. Вероятно, что пропущенные данные не были указаны в объявлении.
#
#
# Отсутствие подобных данных может быть характерно для объектов из категорий `studio` и `open_plan`. Проверим свою гипотезу.

# %%
data.query('(kitchen_area.isnull()) & (studio == True | open_plan == True)')['total_area'].count()
# Out:
# 216

# %% [markdown]
# 9,48% всех пропусков согласуется с нашей гипотезой. Оставим эти пропуски без изменений. Остальные проанализируем.
#
# Найдем коэффициент корреляции Пирсона для общей и кухонной площади.

# %%
data['total_area'].corr(data['kitchen_area'])
# Out:
# 0.6091211711198321

# %% [markdown]
# Положительная корреляция есть, но намного менее выраженная чем между общей и жилой площадью. Оставим и эти пропущенные значения без изменения.

# %% [markdown]
# `balcony`

# %%
data['balcony'].isna().sum()
# Out:
# 11519

# %% [markdown]
# Доля пропусков по столбцу `'balcony'` составляет 48,61%. Вероятно, что пропущенные данные не были указаны в объявлении в связи с тем, что объект не имеет балкона. Заменим пропуски на целочисленное значение '0'.

# %%
data['balcony'] = data['balcony'].fillna(0)

# %%
data['balcony'].isna().sum() #проверка
# Out:
# 0

# %% [markdown]
# `locality_name`

# %%
data['locality_name'].isna().sum()
# Out:
# 49

# %% [markdown]
# Примем радиус Санкт-Петербурга за 18000 м. Для строк, удовлетворяющих условию `'city_сenters_nearest' <= 18000`, заполним пропуски значением "Санкт-Петербург". Остальные пропускип оставим без изменений.

# %%
data.loc[(data['city_сenters_nearest'] <= 18000) & (data['locality_name'].isnull()), 'locality_name'] = 'Санкт-Петербург'

# %% [markdown]
# Посчитаем кол-во пропущенных после замены.

# %%
data['locality_name'].isna().sum()
# Out:
# 12

# %% [markdown]
# Остальные пропуски оставим без изменений.

# %% [markdown]
# `airports_nearest`, `city_сenters_nearest`, `ponds_around_3000`, `parks_around_3000`

# %%
data['airports_nearest'].isna().sum()
# Out:
# 5542

# %%
data['city_сenters_nearest'].isna().sum()
# Out:
# 5519

# %%
data['ponds_around_3000'].isna().sum()
# Out:
# 5518

# %%
data['parks_around_3000'].isna().sum()
# Out:
# 5518

# %% [markdown]
# - Доля пропусков по столбцу `'airports_nearest'` составляет 23,38%.
# - Доля пропусков по столбцу `'city_сenters_nearest'` составляет 23,29%.
# - Доля пропусков по столбцу `'ponds_around_3000'` составляет 23,28%.
# - Доля пропусков по столбцу `'parks_around_3000'` составляет 23,28%.
#
# Вероятно, что в объявлениях не был указан полный адрес из-за чего данные, подгружаемые с карт автоматически, не проставились. Попробуем восстановить часть данных по столбцам `'airports_nearest'` и `'city_сenters_nearest'`. Просмотрим топ-5 проблемных локаций и найдем для них данные в ручном режиме.

# %%
data.query('airports_nearest.isnull()')['locality_name'].value_counts().head(15)
# Out:
# посёлок Мурино             522
# Всеволожск                 398
# Гатчина                    307
# деревня Кудрово            299
# Выборг                     237
# Кудрово                    173
# деревня Новое Девяткино    144
# Сертолово                  142
# Кириши                     125
# Сланцы                     112
# Волхов                     111
# Тосно                      104
# Кингисепп                  104
# Никольское                  93
# Коммунар                    89
# Name: locality_name, dtype: int64

# %%
data.loc[(data['locality_name'] == 'посёлок Мурино') & (data['airports_nearest'].isnull()), 'airports_nearest'] = 32820
data.loc[(data['locality_name'] == 'Всеволожск') & (data['airports_nearest'].isnull()), 'airports_nearest'] = 31340
data.loc[(data['locality_name'] == 'Гатчина') & (data['airports_nearest'].isnull()), 'airports_nearest'] = 27950
data.loc[(data['locality_name'] == 'деревня Кудрово') & (data['airports_nearest'].isnull()), 'airports_nearest'] = 18150
data.loc[(data['locality_name'] == 'Выборг') & (data['airports_nearest'].isnull()), 'airports_nearest'] = 143000
data.loc[(data['locality_name'] == 'Кудрово') & (data['airports_nearest'].isnull()), 'airports_nearest'] = 18150
data.loc[(data['locality_name'] == 'деревня Новое Девяткино') & (data['airports_nearest'].isnull()), 'airports_nearest'] = 34100
data.loc[(data['locality_name'] == 'Сертолово') & (data['airports_nearest'].isnull()), 'airports_nearest'] = 47620
data.loc[(data['locality_name'] == 'Кириши') & (data['airports_nearest'].isnull()), 'airports_nearest'] = 93170
data.loc[(data['locality_name'] == 'Сланцы') & (data['airports_nearest'].isnull()), 'airports_nearest'] = 152410

# %%
data.query('city_сenters_nearest.isnull()')['locality_name'].value_counts().head(10)
# Out:
# посёлок Мурино             522
# Всеволожск                 398
# Гатчина                    307
# деревня Кудрово            299
# Выборг                     237
# Кудрово                    173
# деревня Новое Девяткино    144
# Сертолово                  142
# Кириши                     125
# Сланцы                     112
# Name: locality_name, dtype: int64

# %%
data.loc[(data['locality_name'] == 'посёлок Мурино') & (data['city_сenters_nearest'].isnull()), 'city_сenters_nearest'] = 14010
data.loc[(data['locality_name'] == 'Всеволожск') & (data['city_сenters_nearest'].isnull()), 'city_сenters_nearest'] = 20620
data.loc[(data['locality_name'] == 'Гатчина') & (data['city_сenters_nearest'].isnull()), 'city_сenters_nearest'] = 42190
data.loc[(data['locality_name'] == 'деревня Кудрово') & (data['city_сenters_nearest'].isnull()), 'city_сenters_nearest'] = 11360
data.loc[(data['locality_name'] == 'Выборг') & (data['city_сenters_nearest'].isnull()), 'city_сenters_nearest'] = 121910
data.loc[(data['locality_name'] == 'Кудрово') & (data['city_сenters_nearest'].isnull()), 'city_сenters_nearest'] = 11360
data.loc[(data['locality_name'] == 'деревня Новое Девяткино') & (data['city_сenters_nearest'].isnull()), 'city_сenters_nearest'] = 16090
data.loc[(data['locality_name'] == 'Сертолово') & (data['city_сenters_nearest'].isnull()), 'city_сenters_nearest'] = 25250
data.loc[(data['locality_name'] == 'Кириши') & (data['city_сenters_nearest'].isnull()), 'city_сenters_nearest'] = 110010
data.loc[(data['locality_name'] == 'Сланцы') & (data['city_сenters_nearest'].isnull()), 'city_сenters_nearest'] = 155490

# %% [markdown]
# Посчитаем кол-во пропущенных значений после замен.

# %%
data['airports_nearest'].isna().sum()
# Out:
# 3083

# %%
data['city_сenters_nearest'].isna().sum()
# Out:
# 3060

# %% [markdown]
# После замен доля пропусков снизилась до:
#
# - Доля пропусков по столбцу `'airports_nearest'` составляет 13,01%.
# - Доля пропусков по столбцу `'city_сenters_nearest'` составляет 12,91%.
#
# Остальные пропуски оставим без изменения.

# %% [markdown]
# `parks_nearest`,  `ponds_nearest`

# %%
data['parks_nearest'].isna().sum()
# Out:
# 15620

# %%
data['ponds_nearest'].isna().sum()
# Out:
# 14589

# %% [markdown]
# - Доля пропусков по столбцу `'parks_nearest'` составляет 65,91%.
# - Доля пропусков по столбцу `'ponds_nearest'` составляет 61,56%.
#
# Проверим гипотезу, согласно которой:
#
# - 5518 пропусков связаны с пропусками в столбцах `'ponds_around_3000'` и `'parks_around_3000'`;
# - остальные пропуски возникают в том случае, когда значения `'ponds_around_3000'` и `'parks_around_3000'` равны '0'.

# %%
data.query('(parks_nearest.isna() == True) & (parks_around_3000.isna() == True)')['total_area'].count()
# Out:
# 5518

# %%
data.query('(parks_nearest.isna() == True) & (parks_around_3000 == 0)')['total_area'].count()
# Out:
# 10102

# %%
data.query('(ponds_nearest.isna() == True) & (ponds_around_3000.isna() == True)')['total_area'].count()
# Out:
# 5518

# %%
data.query('(ponds_nearest.isna() == True) & (ponds_around_3000 == 0)')['total_area'].count()
# Out:
# 9071

# %% [markdown]
# Гипотеза подтвердилась. Оставим пропуски без изменений.

# %% [markdown]
# `days_exposition`

# %%
data['days_exposition'].isna().sum()
# Out:
# 3181

# %% [markdown]
# Просмотрим статистические данные.

# %%
data['days_exposition'].describe()
# Out:
# count    20518.000000
# mean       180.888634
# std        219.727988
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Доля пропусков по столбцу `'days_exposition'` составляет 13,42%.
# Возможные варианты возникновения пропусков:
#
# - Существуют разные причины снятия объявления с публикации. Пропусками могут маркироваться причины, не связанные с продажей: например в связи с жалобой на мошенничество и пр;
# - Квартиры, снятые с продажи в день опубликования помечаются как NaN.
#
# Пропуски оставим без изменений.

# %% [markdown]
# **Вывод**

# %% [markdown]
# Подведем итоги произведенных замен. Итоговая таблица пропущенных значений выглядит следующим образом:

# %%
data.isna().sum()
# Out:
# total_images                    0
# last_price                      0
# total_area                      0
# first_day_exposition            0
# rooms                           0
# ceiling_height                  0
# floors_total                   86
# living_area                     0
# floor                           0
# is_apartment                20924
# studio                          0
# open_plan                       0
# kitchen_area                 2278
# balcony                         0
# locality_name                  12
# airports_nearest             3083
# city_сenters_nearest         3060
# parks_around_3000            5518
# parks_nearest               15620
# ponds_around_3000            5518
# ponds_nearest               14589
# days_exposition              3181
# city_сenters_nearest_cut        0
# check                           0
# dtype: int64

# %% [markdown]
# Многие из пропущенных значений не удалось заменить адекватными значениями. Было принято оставить их без изменений.

# %% [markdown]
# ### Замена типа данных

# %% [markdown]
# Просмотрим общую информацию по данным.

# %%
data.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   total_images              23699 non-null  int64
#  1   last_price                23699 non-null  float64
#  2   total_area                23699 non-null  float64
#  3   first_day_exposition      23699 non-null  object
#  4   rooms                     23699 non-null  int64
#  5   ceiling_height            23699 non-null  float64
#  6   floors_total              23613 non-null  float64
#  7   living_area               23699 non-null  float64
#  8   floor                     23699 non-null  int64
#  9   is_apartment              2775 non-null   object
#  10  studio                    23699 non-null  bool
#  11  open_plan                 23699 non-null  bool
#  12  kitchen_area              21421 non-null  float64
# ...

# %% [markdown]
# Проанализируем max и min значения.

# %%
data.describe().T
# Out:
#                         count          mean           std      min        25%  \
# total_images          23699.0  9.858475e+00  5.682529e+00      0.0        6.0
# last_price            23699.0  6.541549e+06  1.088701e+07  12190.0  3400000.0
# total_area            23699.0  6.034865e+01  3.565408e+01     12.0       40.0
# rooms                 23699.0  2.070636e+00  1.078405e+00      0.0        1.0
# ceiling_height        23699.0  2.731975e+00  9.917548e-01      1.0        2.6
# floors_total          23613.0  1.067382e+01  6.597173e+00      1.0        5.0
# living_area           23699.0  3.453545e+01  2.231676e+01      2.0       19.0
# floor                 23699.0  5.892358e+00  4.885249e+00      1.0        2.0
# kitchen_area          21421.0  1.056981e+01  5.905438e+00      1.3        7.0
# balcony               23699.0  5.910798e-01  9.592982e-01      0.0        0.0
# airports_nearest      20616.0  3.123007e+04  1.996122e+04      0.0    18750.0
# ...

# %% [markdown]
# Учитывая полученные ранее данные о кол-ве уникальных значений а также max и min, проведем замены типов данных с помощью метода `astype()`

# %%
try:
    data['total_images'] = data['total_images'].astype('int8')
    data['last_price'] = data['last_price'].astype('int32')
    data['total_area'] = data['total_area'].astype('int32')
    data['rooms'] = data['rooms'].astype('int8')
    data['living_area'] = data['living_area'].astype('int32')
    data['floor'] = data['floor'].astype('int8')
    data['is_apartment'] = data['is_apartment'].astype('category')
    data['studio'] = data['studio'].astype('category')
    data['open_plan'] = data['open_plan'].astype('category') 
    data['parks_around_3000'] = data['parks_around_3000'].astype('category')
    data['ponds_around_3000'] = data['ponds_around_3000'].astype('category')
    
    
        
    data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')
    
except:
    print('Ошибка при попытке изменения типа данных')

# %%
data.info(memory_usage='deep') # проверка
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   total_images              23699 non-null  int8
#  1   last_price                23699 non-null  int32
#  2   total_area                23699 non-null  int32
#  3   first_day_exposition      23699 non-null  datetime64[ns]
#  4   rooms                     23699 non-null  int8
#  5   ceiling_height            23699 non-null  float64
#  6   floors_total              23613 non-null  float64
#  7   living_area               23699 non-null  int32
#  8   floor                     23699 non-null  int8
#  9   is_apartment              2775 non-null   category
#  10  studio                    23699 non-null  category
#  11  open_plan                 23699 non-null  category
#  12  kitchen_area              21421 non-null  float64
# ...

# %% [markdown]
# **Вывод**

# %% [markdown]
# Для оптимизации работы с памятью провели следующие замены типов данных:
# - `category`: 'is_apartment', 'studio', 'open_plan', 'balcony', 'parks_around_3000', 'ponds_around_3000'
# - `int8`: 'total_images', 'rooms', 'floor';
# - `int32`: 'last_price', 'total_area', 'living_area';
# - `datetime64`: 'first_day_exposition'.
#
# Изменение типов данных позволило сократить значение используемой памяти с 9.6 MB до 6.3 MB.

# %% [markdown]
# ### Обработка дубликатов

# %% [markdown]
# Посчитаем кол-во явных совпадений.

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Вывод**

# %% [markdown]
# Явные дубликаты в данных не обнаружены.

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# Добавим данные в таблицу для дальнейшего анализа.

# %%
# цена квадратного метра 
data['price_per_m'] = data['last_price']/data['total_area']

# %%
# день недели, месяц и год
data['day'] = pd.DatetimeIndex(data['first_day_exposition']).weekday
data['month'] = pd.DatetimeIndex(data['first_day_exposition']).month 
data['year'] = pd.DatetimeIndex(data['first_day_exposition']).year

# %% [markdown]
# Заменим цифровое обозначение дня недели буквенным.

# %%
dict_of_weekdays = {0: 'понедельник', 1: 'вторник', 2: 'среда', 3: 'четверг', 
                    4: 'пятница', 5: 'суббота', 6: 'воскресенье'}

# %%
data['day'] = data['day'].map(dict_of_weekdays)

# %% [markdown]
# Добавим категории для этажа.

# %%
data['floor_category'] = np.where(data['floor'] == 1, 'первый', 'другой')
data['floor_category'] = np.where(data['floor'] == data['floors_total'], 'последний', data['floor_category'])

# %% [markdown]
# Добавим данные с соотношение жилой и общей площади, а также отношение площади кухни к общей площади.

# %%
data['living_area_share'] = data['living_area'] / data['total_area']
data['kitchen_area_share'] = data['kitchen_area'] / data['total_area']

# %%
data.head(5).T
# Out:
#                                             0                    1  \
# total_images                               20                    7
# last_price                           13000000              3350000
# total_area                                108                   40
# first_day_exposition      2019-03-07 00:00:00  2018-12-04 00:00:00
# rooms                                       3                    1
# ceiling_height                            2.7                  2.6
# floors_total                             16.0                 11.0
# living_area                                51                   18
# floor                                       8                    1
# is_apartment                              NaN                  NaN
# studio                                  False                False
# open_plan                               False                False
# kitchen_area                             25.0                 11.0
# ...

# %% [markdown]
# **Вывод**

# %% [markdown]
# В таблицу для дальнейшего анализа добавили следующие данные:
#
#     цену квадратного метра;
#     день недели, месяц и год публикации объявления;
#     этаж квартиры (первый, последний, другой);
#     соотношение жилой и общей площади;
#     отношение площади кухни к общей площади.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Изучаем параметры: площадь, цена, число комнат, высота потолков.

# %% [markdown]
# Просмотрим статистические данные.

# %%
data[['total_area', 'last_price', 'rooms', 'ceiling_height']].describe()
# Out:
#          total_area    last_price         rooms  ceiling_height
# count  23699.000000  2.369900e+04  23699.000000    23699.000000
# mean      60.120511  6.541549e+06      2.070636        2.731975
# std       35.665822  1.088701e+07      1.078405        0.991755
# min       12.000000  1.219000e+04      0.000000        1.000000
# 25%       40.000000  3.400000e+06      1.000000        2.600000
# 50%       52.000000  4.650000e+06      2.000000        2.640000
# 75%       69.000000  6.800000e+06      3.000000        2.750000
# max      900.000000  7.630000e+08     19.000000      100.000000

# %%
data['last_price'].mean()
# Out:
# 6541548.771551542

# %% [markdown]
#  - Площадь квартиры колеблется в диапазоне 12-900 м. Среднее значение 60,12 м
#  - Цена квартиры колеблется в диапазоне 12190-763000000 руб. Среднее значение 6541549 руб.
#  - Число комнат колеблется в диапазоне 0-19. Среднее значение 2
#  - Высота потолков колеблется в диапазоне 1-100 м. Среднее значение 2.18

# %% [markdown]
# Определим граничные данные без вбросов и построим гистограммы.

# %%
data[['total_area']].boxplot()
plt.ylim(0, 200)
# Out:
# (0.0, 200.0)

# %%
data['total_area'].hist(bins=20, range=(15, 115))
plt.xlabel('Площадь квартиры')
plt.ylabel('Количество квартир (шт.)')
plt.title('Распределение площадей (2014-2019 г.)')
plt.legend = True

# %% [markdown]
# Большинство квартир имеют площадь 30-60 м2.

# %%
data[['last_price']].boxplot()
plt.ylim(0, 16000000)
# Out:
# (0.0, 16000000.0)

# %%
data['last_price'].hist(bins=70, range=(0, 12000000), figsize=(10,5))
plt.xlabel('Цена квартиры')
plt.ylabel('Количество квартир (шт.)')
plt.title('Распределение цен (2014-2019 г.)')
plt.legend = True

# %% [markdown]
# Самые покупаемые квартиры стоят около 4 млн. руб.

# %%
data[['rooms']].boxplot()
plt.ylim(0, 10)
# Out:
# (0.0, 10.0)

# %%
data['rooms'].hist(bins=20, range=(0, 6))
plt.xlabel('Число комнат')
plt.ylabel('Количество квартир (шт.)')
plt.title('Распределение по числу комнат (2014-2019 г.)')
plt.legend = True

# %% [markdown]
# Наибольшим спросом пользуются одно- и двухкомнатные квартиры.

# %%
data[['ceiling_height']].boxplot()
plt.ylim(2.3, 3.25)
# Out:
# (2.3, 3.25)

# %%
data['ceiling_height'].hist(bins=8, range=(2.4, 3))
plt.xlabel('Высота потолков')
plt.ylabel('Количество квартир (шт.)')
plt.title('Распределение по высоте потолков (2014-2019 г.)')
plt.legend = True

# %% [markdown]
# Стандатная высота потолков - 2,64 м.

# %% [markdown]
# **Вывод**

# %% [markdown]
# Изучение таких параметров как [площадь, цена, число комнат, высота потолков] выявило следующие средние показатели:
#
#     площадь: 30-60 м2
#     цена: 4 млн.
#     число комнат: 1-2
#     высота потолков: 2,64 м

# %% [markdown]
# ### Изучаем время продажи квартиры

# %%
data['days_exposition'].hist(bins=70, figsize=(10,5))
plt.xlabel('Количество дней')
plt.ylabel('Количество квартир (шт.)')
plt.title('Время продажи квартиры (2014-2019 г.)')
plt.legend = True

# %% [markdown]
# Определим граничные данные без вбросов и построим гистограмму.

# %%
data[['days_exposition']].boxplot()
plt.ylim(0, 600)
# Out:
# (0.0, 600.0)

# %% [markdown]
# Ограничим данные 500 днями.

# %%
data.query('days_exposition<=500')['days_exposition'].hist(bins=70, figsize=(10,5))
plt.xlabel('Количество дней')
plt.ylabel('Количество квартир (шт.)')
plt.title('Время продажи квартиры (2014-2019 г.)')
plt.legend = True

# %% [markdown]
# Изучим статистические данные.

# %%
data[['days_exposition']].describe()
# Out:
#        days_exposition
# count     20518.000000
# mean        180.888634
# std         219.727988
# min           1.000000
# 25%          45.000000
# 50%          95.000000
# 75%         232.000000
# max        1580.000000

# %% [markdown]
# Среднее время продажи квартиры - 181 день, значение медианы - 95 дней.
# Можно считать, что продажа прошла быстро, если срок составил менее 45 дней. И наоборот, квартира продавалась дольше обычного, если срок превысил 232 дня.
#
# Рассмотрим более подробно интервал 40-100 дней.

# %%
data.query('days_exposition<500')['days_exposition'].hist(bins=70, figsize=(10,5), range=(25, 100))
plt.xlabel('Количество дней')
plt.ylabel('Количество квартир (шт.)')
plt.title('Время продажи квартиры (2014-2019 г.)')
plt.legend = True

# %% [markdown]
# Наблюдаются пики на значениях 30, 45, 60 и 90 дней. Возможно, это связано с тем что объявление закрываются автоматически по результатам запроса/опроса в указанные даты.

# %% [markdown]
# **Вывод**

# %% [markdown]
# Изучение данных о времени продажи квартир выявило следующие закономерности:
#
#     - день: максимальная цена продажи характерна для субботы, минимальная для воскресенья.
#     - месяц: цены квартир поднимаются к концу года.
#     - год: взрывной 2014 год, далее спад и стабилизация.

# %% [markdown]
# ### Изучаем факторы больше всего влияющие на стоимость квартиры

# %% [markdown]
# #### Зависимость цены квартиры от площади

# %% [markdown]
# Рассчитаем коэффициент корреляции Пирсона.

# %%
data['total_area'].corr(data['last_price'])
# Out:
# 0.6536539818654248

# %% [markdown]
# Коэффициент корреляции положителен и > 50%, что говорит о достаточно выраженной прямой зависимости.
# Определим вбросы.

# %%
data[['total_area']].boxplot()
plt.ylim(0, 200)
# Out:
# (0.0, 200.0)

# %% [markdown]
# Построим график зависимости.

# %%
data.query('total_area < 120').plot(x='total_area', y='last_price', kind='scatter', figsize=(10, 6), grid=True) 
plt.ylim(0, 60000000) 
plt.xlabel('Общая плошадь')
plt.ylabel('Цена продажи (руб.)')
plt.title('Зависимость цены квартиры от общей площади (2014-2019 г.)')
plt.legend = True

# %% [markdown]
# Есть общий положительный тренд. При этом начиная где-то с 50 м. начинают появляться объекты, на цену которых влияют другие факторы, что выбивает их из общего тренда.

# %% [markdown]
# #### Зависимость цены квартиры от числа комнат

# %% [markdown]
# Рассчитаем коэффициент корреляции Пирсона.

# %%
data['rooms'].corr(data['last_price'])
# Out:
# 0.3633428499648938

# %% [markdown]
# Коэффициент положительный, но менее 50%. Зависимость есть, но не четко выраженная. Определим вбросы.

# %%
data[['rooms']].boxplot()
plt.ylim(0, 10)
# Out:
# (0.0, 10.0)

# %% [markdown]
# Построим график зависимости.

# %%
data.query('rooms <= 6').pivot_table(index=['rooms'],values='last_price').plot(kind='bar', figsize=(8, 6), grid=True) 
plt.xlabel('Число комнат')
plt.ylabel('Цена продажи (руб.)')
plt.title('Зависимость цены квартиры от числа комнат (2014-2019 г.)')
plt.legend = True

# %% [markdown]
# Чем больше комнат, тем выше цена.

# %% [markdown]
# #### Зависимость цены квартиры от удаленности от центра

# %% [markdown]
# Рассчитаем коэффициент корреляции Пирсона.

# %%
data['city_сenters_nearest'].corr(data['last_price'])
# Out:
# -0.1530700318055155

# %% [markdown]
# Значение коээфициента меньше 0, что говорит об обратной зависимости.
#
# Построим график используя введенные ранее категории.

# %%
data.pivot_table(index=['city_сenters_nearest_cut'],values='last_price').plot(kind='bar', figsize=(9, 6), grid=True) 
plt.xlabel('Удаленность от центра')
plt.ylabel('Цена продажи (руб.)')
plt.title('Зависимость цены квартиры от удаленности от центра (2014-2019 г.)')
plt.legend = True

# %% [markdown]
# Чем дальше от центра, тем квартиры дешевле.

# %% [markdown]
# #### Зависимость цены квартиры от этажа

# %% [markdown]
# Построим график используя введенные ранее категории.

# %%
data.pivot_table(index=['floor_category'],values='last_price').plot(kind='bar', figsize=(7, 6), grid=True) 
plt.xlabel('Этаж')
plt.ylabel('Цена продажи (руб.)')
plt.title('Зависимость цены квартиры от этажа (2014-2019 г.)')
plt.legend = True

# %% [markdown]
# Цена квартир на первом этаже ниже.

# %% [markdown]
# #### Зависимость цены квартиры от даты размещения

# %% [markdown]
# Построим графики используя введенные ранее категории.

# %%
data.pivot_table(index=['day'],values='last_price').plot(kind='bar', figsize=(10, 5), grid=True) 
plt.xlabel('День недели')
plt.ylabel('Цена продажи (руб.)')
plt.title('Зависимость цены квартиры от дня продажи (2014-2019 г.)')
plt.legend = True

# %% [markdown]
# Рассмотри более подробно граничные данные.

# %%
data.pivot_table(index=['day'],values='last_price').plot(kind='bar', figsize=(10, 5), grid=True) 
plt.xlabel('День недели')
plt.ylabel('Цена продажи (руб.)')
plt.title('Зависимость цены квартиры от дня продажи (2014-2019 г.)')
plt.ylim(5000000, 8000000)
plt.legend = True

# %% [markdown]
# Сильных разбросов не наблюдается, лучшая средняя цена характерна для субботы, худшая - для воскресенья.

# %%
data.pivot_table(index=['month'],values='last_price').plot(kind='bar', figsize=(10, 5), grid=True) 
plt.xlabel('Месяц')
plt.ylabel('Цена продажи (руб.)')
plt.title('Зависимость цены квартиры от месяца продажи (2014-2019 г.)')
plt.legend = True

# %% [markdown]
# Рассмотри более подробно граничные данные.

# %%
data.pivot_table(index=['month'],values='last_price').plot(kind='bar', figsize=(10, 5), grid=True) 
plt.xlabel('Месяц')
plt.ylabel('Цена продажи (руб.)')
plt.title('Зависимость цены квартиры от месяца продажи (2014-2019 г.)')
plt.ylim(5000000, 8000000)
plt.legend = True

# %% [markdown]
# Сильных разбросов не наблюдается, лучшая средняя цена характерна для декабря, худщая для октября.

# %%
data.pivot_table(index=['year'],values='last_price').plot(kind='bar', figsize=(10, 5), grid=True) 
plt.xlabel('Год')
plt.ylabel('Цена продажи (руб.)')
plt.title('Зависимость цены квартиры от года продажи (2014-2019 г.)')
plt.legend = True

# %% [markdown]
# Судя по графику, пиковые цены на недвижимость были в 2014 году, после чего цена достаточно резко упала и продолжает держаться на том же уровне. Рассмотри детальнее 2014 год.

# %%
data.query('year == 2014').pivot_table(index=['month'],values='last_price').plot(kind='bar', figsize=(6, 3), grid=True)
plt.xlabel('Месяц')
plt.ylabel('Цена продажи (руб.)')
plt.title('Продажи в 2014 году')
plt.legend = True

# %% [markdown]
# За 2014 год есть данные только за октябрь и декабрь.
#
# В целом, судя по публикациям в прессе, 2014 год был нестандартным для недвижимости.

# %% [markdown]
# #### Топ-10 населённых пунктов с наибольшим числом объявлений

# %% [markdown]
# Выберем 10 населённых пунктов с наибольшим числом объявлений. Посчитаем среднюю цену квадратного метра в этих населённых пунктах. Выделим населённые пункты с самой высокой и низкой стоимостью жилья за квадратный метр.

# %%
top10 = data['locality_name'].value_counts().index.tolist()[:10]
top10_price_per_m = [data[data['locality_name'] == city]['price_per_m'].median() for city in top10]
top10_last_price_median = [data[data['locality_name'] == city]['last_price'].median() for city in top10]
top10_count = [data[data['locality_name'] == city]['last_price'].count() for city in top10]
df = {'Город': top10, 'Средняя цена за кв.м.': top10_price_per_m, 'Средняя цена за квартиру': top10_last_price_median, 'Кол-во обявлений': top10_count}
pd.DataFrame(df).sort_values(by='Средняя цена за кв.м.', ascending=False)
# Out:
#                Город  Средняя цена за кв.м.  Средняя цена за квартиру  \
# 0    Санкт-Петербург          105263.157895                 5500000.0
# 4             Пушкин          100000.000000                 5180000.0
# 8    деревня Кудрово           92647.058824                 3790000.0
# 6  посёлок Парголово           92222.222222                 4100000.0
# 1     посёлок Мурино           86410.969793                 3400000.0
# 2     посёлок Шушары           77223.320158                 3950000.0
# 5            Колпино           74861.111111                 3600000.0
# 7            Гатчина           67924.528302                 3100000.0
# 3         Всеволожск           65811.403509                 3450000.0
# 9             Выборг           58333.333333                 2897000.0
#
#    Кол-во обявлений
# 0             15758
# 4               369
# 8               299
# 6               327
# 1               522
# 2               440
# 5               338
# 7               307
# ...

# %% [markdown]
# Самые дорогие квартиры в Санкт-Петербурге и городе Пушкине. Чем дальше от Санкт-Петербурга, тем дешевле. В Выборге цена за квадратный метр почти в 2 раз ниже, чем в Санкт-Петербурге.

# %% [markdown]
# #### Определение границ центра Санкт-Петербурга

# %% [markdown]
# Выделим квартиры в Санкт-Петербурге. Создадим столбец с расстоянием до центра в километрах, округлим до целых значений. После этого посчитаем среднюю цену для каждого километра. Построим график: он будет показывать, как цена зависит от удалённости от центра. Определим границу, где график сильно меняется — это и будет центральная зона.

# %%
data['city_сenters_nearest_km'] = (data['city_сenters_nearest']/1000).round()
data_spb = data.query('locality_name == "Санкт-Петербург"')
data_spb.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000         108           2019-03-07      3
# 2            10     5196000          56           2015-08-20      2
# 3             0    64900000         159           2015-07-24      3
# 4             2    10000000         100           2018-06-19      2
# 7             5     7915000          71           2019-04-18      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0           51      8          NaN  ...
# 2            2.64           5.0           34      4          NaN  ...
# 3            2.64          14.0           89      9          NaN  ...
# 4            3.03          14.0           32     13          NaN  ...
# 7            2.64          24.0           40     22          NaN  ...
#
#   city_сenters_nearest_cut  check    price_per_m      day month  year  \
# ...

# %% [markdown]
# Построим график зависимости цены от расстояния до центра.

# %%
data_spb.pivot_table(index=['city_сenters_nearest_km'],values='last_price').plot(kind='bar', figsize=(13, 5), grid=True)
plt.xlabel('Расстояние до центра')
plt.ylabel('Цена продажи (руб.)')
plt.title('Зависимость цены квартиры от расстояния до центра в городе Санкт-Петербург (2014-2019 г.)')
plt.legend = True

# %% [markdown]
# По графику можно выделить две центральные зоны:
#
#     - до 1 км
#     - до 8 км
# Центром города будем считать зону в пределах 8 км.

# %% [markdown]
# #### Анализ сегмента квартир в центре Санкт-Петербурга

# %% [markdown]
# Отфильтруем квартиры в центре.

# %%
data_spb_center = data_spb.query('city_сenters_nearest <= 8000')

# %% [markdown]
# Сравним распределение по площади квартир в центре С-П и по всей выборке.

# %%
data_spb_center['total_area'].hist(bins=20, range=(15, 115))
plt.xlabel('Площадь квартиры')
plt.ylabel('Цена продажи (руб.)')
plt.title('Распределение площадей в центре С-П (2014-2019 г.)')
plt.legend = True

# %%
data['total_area'].hist(bins=20, range=(15, 115))
plt.xlabel('Площадь квартиры')
plt.ylabel('Цена продажи (руб.)')
plt.title('Распределение площадей общая выборка (2014-2019 г.)')
plt.legend = True

# %% [markdown]
# Квартиры в центре С-П имеют большие площади.

# %% [markdown]
# Сравним распределение по цене квартир в центре С-П и по всей выборке.

# %%
data_spb_center['last_price'].hist(bins=70, range=(0, 12000000), figsize=(10,5))
plt.xlabel('Цена квартиры')
plt.ylabel('Кол-во квартир (шт.)')
plt.title('Распределение цен в центре С-П (2014-2019 г.)')
plt.legend = True

# %%
data['last_price'].hist(bins=70, range=(0, 12000000), figsize=(10,5))
plt.xlabel('Цена квартиры')
plt.ylabel('Кол-во квартир (шт.)')
plt.title('Распределение цен общая выборка (2014-2019 г.)')
plt.legend = True

# %% [markdown]
# График цен в центре явно смещен вправо, в сторону увеличения цены. При этом наблюдается много разны пиков.

# %% [markdown]
# Сравним распределение по числу комнат в центре С-П и по всей выборке.

# %%
data_spb_center['rooms'].hist(bins=20, range=(0, 6))
plt.xlabel('Число комнат')
plt.ylabel('Кол-во квартир (шт.)')
plt.title('Число комнат в центре С-П (2014-2019 г.)')
plt.legend = True

# %%
data['rooms'].hist(bins=20, range=(0, 6))
plt.xlabel('Число комнат')
plt.ylabel('Кол-во квартир (шт.)')
plt.title('Число комнат общая выборка (2014-2019 г.)')
plt.legend = True

# %% [markdown]
# В центре С-П большинство квартир с 3 и 2 комнатами, по общей выборке - с 1 и 2 комнатами.

# %% [markdown]
# Сравним распределение по высоте потолков в центре С-П и по всей выборке.

# %%
data_spb_center['ceiling_height'].hist(bins=8, range=(2.4, 3))
plt.xlabel('Высота потолков')
plt.ylabel('Кол-во квартир (шт.)')
plt.title('Распределение по высоте потолков в центре С-П (2014-2019 г.)')
plt.legend = True

# %%
data['ceiling_height'].hist(bins=8, range=(2.4, 3))
plt.xlabel('Высота потолков')
plt.ylabel('Кол-во квартир (шт.)')
plt.title('Распределение по высоте потолков общая выборка (2014-2019 г.)')
plt.legend = True

# %% [markdown]
# В центре С-П большинство квартир имеют высоту потолков 3 м, тогда как по всей выборке этот показатель 2,64 м.

# %% [markdown]
# Проанализирем факторы, влияющие на стоимость квартир в центре Санкт-Петербурга.

# %%
data_spb_center.corr().sort_values(by='last_price', ascending=False).head(6)
# Out:
#               total_images  last_price  total_area     rooms  ceiling_height  \
# last_price        0.131776    1.000000    0.636426  0.333047        0.077150
# price_per_m       0.159361    0.778760    0.249387  0.003851        0.044907
# total_area        0.099247    0.636426    1.000000  0.736687        0.133368
# living_area       0.080226    0.558957    0.946755  0.797021        0.144646
# kitchen_area      0.135169    0.508379    0.574745  0.285051        0.078805
# rooms             0.052166    0.333047    0.736687  1.000000        0.104043
#
#               floors_total  living_area     floor  kitchen_area   balcony  \
# last_price        0.043643     0.558957  0.126028      0.508379  0.062892
# price_per_m       0.110155     0.180193  0.124830      0.349994  0.119749
# total_area       -0.021697     0.946755  0.104306      0.574745  0.006365
# living_area      -0.111089     1.000000  0.030600      0.424283 -0.028231
# ...

# %% [markdown]
# Наибольшее влияние на цену квартиры в центре Санкт-Петербурга влияют следующие факторы:
#
#     - цена за метр, коэффициент корелляции 77,88%
#     - общая площадь, коэффициент корелляции 63,64%
#     - жилая площадь, коэффициент корелляции 55,90%
#     - площадь кухни, коэффициент корелляции 50,84%
#     - кол-во комнат, коэффициент корелляции 33,30%

# %% [markdown]
# Проанализирем факторы, влияющие на стоимость квартир по общей выборке.

# %%
data.corr().sort_values(by='last_price', ascending=False).head(6)
# Out:
#               total_images  last_price  total_area     rooms  ceiling_height  \
# last_price        0.104473    1.000000    0.653654  0.363343        0.080945
# price_per_m       0.132756    0.734531    0.298678  0.052191        0.119430
# total_area        0.115110    0.653654    1.000000  0.758347        0.098856
# living_area       0.102570    0.585783    0.945948  0.827753        0.097554
# kitchen_area      0.104756    0.519869    0.609049  0.269945        0.084234
# rooms             0.099288    0.363343    0.758347  1.000000        0.062372
#
#               floors_total  living_area     floor  kitchen_area   balcony  \
# last_price       -0.006984     0.585783  0.026576      0.519869  0.008559
# price_per_m       0.149262     0.228909  0.129872      0.395776  0.023492
# total_area       -0.076034     0.945948 -0.024955      0.609049  0.009833
# living_area      -0.160212     1.000000 -0.090151      0.434856 -0.010422
# ...

# %% [markdown]
# Наибольшее влияние на цену квартиры по всей выборке влияют следующие факторы:
#
#     - цена за метр, коэффициент корелляции 73,45%
#     - общая площадь, коэффициент корелляции 65,37%
#     - жилая площадь, коэффициент корелляции 58,57%
#     - площадь кухни, коэффициент корелляции 51,99%
#     - кол-во комнат, коэффициент корелляции 36,33%

# %% [markdown]
# На стоимость квартиры в центре Санкт-Петербурга и вцелом по выборке влияют одни и теже параметры.

# %% [markdown]
# **Вывод**

# %% [markdown]
# Проанализирована зависимость цены продажи от следующих величин:
#
#  - Общая площадь квартиры: зависимость прямая, чем больше площадь тем выше цена.
#  - Удаленность от центра: зависимость обратная, чем больше удаленность от центра тем ниже цена.
#  - Этаж: квартиры на первом этаже стоят дешевле остальных.
#  - Год: самые высокие цены характерны для 2014 года.
#  - Месяц: повышение цен отмечается в декабре .
#  - День недели: повышение цен отмечается в субботу.
#
# Различий по влиянию основных факторов на квартиры в центре Санкт-Петербурга и в целом по выборке не выявлено.
# Квартиры в центре Санкт-Петербурга имеют ряд отличий от средней выборки:
#
#     - характерная высота потолков 3 м, против 2,64 м по общей выборке.
#     - характерное кол-во комнат 2-3, против 1-2 по общей выборке.
#     - цена квартир значительно выше средней.
#     - общая площадь квартир выше средней.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Наибольшее влияние на стоимость квартиры имеют следующие параметры:
#
# - Цена за метр: чем выше этот показатель, тем выше стоимость квартиры.
# - Общая площадь: чем выше этот показатель, тем выше стоимость квартиры.
# - Жилая площадь/площадь кухни: чем выше эти показатели, тем выше стоимость квартиры.
# - Кол-во комнат: чем выше этот показатель, тем выше стоимость квартиры.
#
# Выявленные взаимосвязи:
#
# - Этаж: стоимость квартиры на первом этаже ниже.
# - День недели: сильных разбросов не наблюдается, пиковая цена продажи приходится на субботу, наименьшая - на воскресенье.
# - Месяц: сильных разбросов не наблюдается, пиковые цены отмечаются в декабре, наименьшие в октябре.
# - Год: для 2014 года характерны пиковые показатели стоимости квартир, далее отмечается спад и стабилизация.
